# %% [markdown]
# ##  **Python Project 2: Blikit Sales Data Analysis**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###  **Importing csv file from the system**

# %%
df=pd.read_csv("C:/Users/ADMIN/OneDrive/Desktop/PYTHON FULL COURSE/Excel Data for Python/Python_Project_2/blinkit_data.csv")

# %%
df
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 0             Regular           FDX32  Fruits and Vegetables
# 1             Low Fat           NCB42     Health and Hygiene
# 2             Regular           FDR28           Frozen Foods
# 3             Regular           FDL50                 Canned
# 4             Low Fat           DRI25            Soft Drinks
# ...               ...             ...                    ...
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                          2012            OUT049               Tier 1
# 1                          2022            OUT018               Tier 3
# ...

# %%
df.head(10)
# Out:
#   Item Fat Content Item Identifier              Item Type  \
# 0          Regular           FDX32  Fruits and Vegetables
# 1          Low Fat           NCB42     Health and Hygiene
# 2          Regular           FDR28           Frozen Foods
# 3          Regular           FDL50                 Canned
# 4          Low Fat           DRI25            Soft Drinks
# 5          low fat           FDS52           Frozen Foods
# 6          Low Fat           NCU05     Health and Hygiene
# 7          Low Fat           NCD30              Household
# 8          Low Fat           FDW20  Fruits and Vegetables
# 9          Low Fat           FDX25                 Canned
#
#    Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 0                       2012            OUT049               Tier 1
# 1                       2022            OUT018               Tier 3
# 2                       2010            OUT046               Tier 1
# ...

# %% [markdown]
# ### **No of Rows and Columns**

# %%
print("The shape of data:",df.shape)
# Out:
# The shape of data: (8523, 12)

# %% [markdown]
# ### **Colomns Names**

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %% [markdown]
# ### **Show The Overall info About the Data**

# %% [markdown]
# #### **Type of data,columns,count of rows,Null values,Type of data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item Fat Content           8523 non-null   object
#  1   Item Identifier            8523 non-null   object
#  2   Item Type                  8523 non-null   object
#  3   Outlet Establishment Year  8523 non-null   int64
#  4   Outlet Identifier          8523 non-null   object
#  5   Outlet Location Type       8523 non-null   object
#  6   Outlet Size                8523 non-null   object
#  7   Outlet Type                8523 non-null   object
#  8   Item Visibility            8523 non-null   float64
#  9   Item Weight                7060 non-null   float64
#  10  Sales                      8523 non-null   float64
#  11  Rating                     8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ### **Data Cleaning**

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat' 'low fat' 'LF' 'reg']

# %% [markdown]
# #### **Used replace funcation for cleaning**

# %%
df['Item Fat Content']=df['Item Fat Content'].replace({
    'low fat':'Low Fat',
'LF':'Low Fat',
'reg':'Regular'})

# %% [markdown]
# ##### **Got clean from the Item Fat Content**

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat']

# %% [markdown]
# ## **BUSINESS REQUIREMENT**

# %% [markdown]
# ## **KPIs REQUIREMENT**

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %%
#Total Sales from all items
Total_Sales=df['Sales'].sum()


#Average Sale
Avg_Sale=df['Sales'].mean()

#No Of Item Sold
No_Of_Item_Sold=df['Sales'].count()

#Average Rating
Avg_Rating=df['Rating'].mean()








print(f"Total Sales: ${Total_Sales:,.2f}")
print(f"Average Sale: ${Avg_Sale:,.2f}")
print(f"No Of Item Sold: {No_Of_Item_Sold:}")
print(f"Average Rating: {Avg_Rating:,.2f}")
# Out:
# Total Sales: $1,201,681.48
# Average Sale: $140.99
# No Of Item Sold: 8523
# Average Rating: 3.97

# %% [markdown]
# ## **Visuals For The Analysis**

# %% [markdown]
# ### **Sales Based on Fat Content**

# %%
Sales_by_fat = df.groupby('Item Fat Content')['Sales'].sum()

plt.pie(Sales_by_fat,
        labels=Sales_by_fat.index,
        autopct='%.2f%%',
        startangle=90)

plt.axis("equal")
plt.title("Sales By Fat Content")
plt.show()

# %% [markdown]
# ### **Total Sales by item type**

# %%
Total_Sales_By_Item_Type=df.groupby('Item Type')['Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(13, 5))

bars=plt.bar(Total_Sales_By_Item_Type.index,
        Total_Sales_By_Item_Type.values)


plt.xticks(rotation=90)
plt.title("Sales Item Type")
plt.xlabel("Item Type")
plt.ylabel("Total Sales")

for bar in bars:
    plt.text(bar.get_x()+bar.get_width()/2,bar.get_height(),
             f'{bar.get_height():,.1f}', ha='center',va='bottom',fontsize=8)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Total Sales Based On Outlet Location And Item Fat Content**

# %%
Content_Outlet_Sales=df.groupby(['Outlet Location Type','Item Fat Content'])['Sales'].sum().unstack()
Content_Outlet_Sales=Content_Outlet_Sales[['Regular','Low Fat']]

ax = Content_Outlet_Sales.plot(kind='bar',figsize=(10,5))


plt.xlabel("Outlet Location Type")
plt.ylabel("Total Sales")
plt.legend(title='Item Fat Content')


plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %% [markdown]
# ### **Total Sales Based on Establishment year of outlet**

# %%
Sales_by_year=df.groupby('Outlet Establishment Year')['Sales'].sum().sort_index()


plt.figure(figsize=(10,5))
plt.plot(Sales_by_year.index,Sales_by_year.values)


plt.title("Sales Based on Outlet Establishment Year")
plt.xlabel("Outlet Establishment Year")
plt.ylabel("Total Sales")


for x,y in zip(Sales_by_year.index,Sales_by_year.values):
    plt.text(x,y,f'{y:,.0f}',ha='center',va='bottom',fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Sales by Outlet Size**

# %%
Sales_By_Outlet_Size=df.groupby('Outlet Size')['Sales'].sum()

plt.figure(figsize=(4,4))
plt.pie(Sales_By_Outlet_Size,
        labels=Sales_By_Outlet_Size.index,
         autopct='%1.2f%%',
          startangle=90)
plt.title("Sales based on the size of the outlet")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Sales by location**

# %%
Sales_by_location=df.groupby('Outlet Location Type')['Sales'].sum().reset_index()

plt.figure(figsize=(10,4))
Sales_by_location=Sales_by_location.sort_values('Sales',ascending=False)

ax=sns.barplot(x='Sales',y='Outlet Location Type',data=Sales_by_location)


plt.title("Sales Based on Outlet Location")
plt.xlabel("Total Sales")
plt.ylabel("Outlet Location Type")

plt.tight_layout()
plt.show()
